# %% [markdown]
# ## ETL Project
# ### Bee Colony Disorders
# ### Tables compiled from the USDA survey data

# %% [markdown]
# Imported necessary modules

# %%
import requests
import numpy as np
import pandas as pd
import time
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats

# %% [markdown]
# Retrieved data from the usda website using the api key via JSON.

# %%
apikey = "15B191E7-B8C5-3AF1-9E28-97FD910F9119"
usda_url ="http://quickstats.nass.usda.gov/api/api_GET/?key=15B191E7-B8C5-3AF1-9E28-97FD910F9119&source_desc=SURVEY&commodity_desc=HONEY&agg_level_desc=STATE&param=short_desc"
usda_data= requests.get(usda_url).json()
usda_data
# Out:
# {'data': [{'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2020,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '5.43',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_name': 'ALABAMA',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'state_fips_code': '01',
#    'state_ansi': '01',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'ALABAMA',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'AL',
#    'class_desc': 'ALL CLASSES'},
#   {'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_desc': '',
#    'state_name': 'ALABAMA',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'region_desc': '',
#    'location_desc': 'ALABAMA',
#    'county_ansi': '',
#    'county_code': '',
#    'watershed_desc': '',
#    'week_ending': '',
#    'state_fips_code': '01',
#    'state_ansi': '01',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_alpha': 'AL',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'year': 2019,
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'Value': '3.38',
#    'watershed_code': '00000000'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'freq_desc': 'ANNUAL',
#    'Value': '3.72',
#    'watershed_code': '00000000',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'year': 2018,
#    'region_desc': '',
#    'location_desc': 'ALABAMA',
#    'county_ansi': '',
#    'county_code': '',
#    'watershed_desc': '',
#    'week_ending': '',
#    'source_desc': 'SURVEY',
#    'state_ansi': '01',
#    'state_fips_code': '01',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_alpha': 'AL',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_desc': '',
#    'state_name': 'ALABAMA',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': ''},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'ARIZONA',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AZ',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'ARIZONA',
#    'state_ansi': '04',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '04',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'year': 2020,
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.18',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000'},
#   {'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '2.04',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'year': 2019,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'state_alpha': 'AZ',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'location_desc': 'ARIZONA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_ansi': '04',
#    'state_fips_code': '04',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'ARIZONA',
#    'commodity_desc': 'HONEY'},
#   {'state_name': 'ARIZONA',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '04',
#    'state_ansi': '04',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'ARIZONA',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'AZ',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2018,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '3.01',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'Value': '1.8',
#    'freq_desc': 'ANNUAL',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'year': 2020,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '05',
#    'state_ansi': '05',
#    'watershed_desc': '',
#    'week_ending': '',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'ARKANSAS',
#    'region_desc': '',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AR',
#    'commodity_desc': 'HONEY',
#    'state_name': 'ARKANSAS',
#    'asd_desc': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '1.65',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'year': 2019,
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'ARKANSAS',
#    'state_fips_code': '05',
#    'state_ansi': '05',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AR',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'ARKANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': ''},
#   {'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '1.88',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'load_time': '2020-03-19 15:06:59',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2018,
#    'state_ansi': '05',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '05',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'ARKANSAS',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AR',
#    'commodity_desc': 'HONEY',
#    'state_name': 'ARKANSAS',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '1.78',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'year': 2020,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'state_alpha': 'CA',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'location_desc': 'CALIFORNIA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '06',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '06',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'CALIFORNIA',
#    'commodity_desc': 'HONEY'},
#   {'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'CALIFORNIA',
#    'state_ansi': '06',
#    'state_fips_code': '06',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'watershed_desc': '',
#    'week_ending': '',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'CA',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'CALIFORNIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '1.6',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'year': 2019},
#   {'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'CALIFORNIA',
#    'commodity_desc': 'HONEY',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'CA',
#    'class_desc': 'ALL CLASSES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '06',
#    'state_ansi': '06',
#    'source_desc': 'SURVEY',
#    'location_desc': 'CALIFORNIA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'year': 2018,
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2020-03-19 15:06:59',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'Value': '2.11',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'year': 2020,
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'Value': '2.09',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'state_name': 'COLORADO',
#    'commodity_desc': 'HONEY',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '08',
#    'source_desc': 'SURVEY',
#    'state_ansi': '08',
#    'location_desc': 'COLORADO',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'CO',
#    'class_desc': 'ALL CLASSES'},
#   {'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'state_name': 'COLORADO',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'region_desc': '',
#    'location_desc': 'COLORADO',
#    'county_ansi': '',
#    'county_code': '',
#    'week_ending': '',
#    'watershed_desc': '',
#    'state_ansi': '08',
#    'state_fips_code': '08',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_alpha': 'CO',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'year': 2019,
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.34',
#    'watershed_code': '00000000'},
#   {'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'COLORADO',
#    'asd_desc': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'CO',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_ansi': '08',
#    'state_fips_code': '08',
#    'watershed_desc': '',
#    'week_ending': '',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'COLORADO',
#    'region_desc': '',
#    'year': 2018,
#    'load_time': '2020-03-19 15:06:59',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'Value': '2.05',
#    'freq_desc': 'ANNUAL',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'class_desc': 'ALL CLASSES',
#    'state_alpha': 'FL',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'FLORIDA',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '12',
#    'state_ansi': '12',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'FLORIDA',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.28',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'year': 2020,
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL'},
#   {'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'FLORIDA',
#    'commodity_desc': 'HONEY',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'FL',
#    'class_desc': 'ALL CLASSES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '12',
#    'source_desc': 'SURVEY',
#    'state_ansi': '12',
#    'location_desc': 'FLORIDA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'year': 2019,
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'Value': '2.46',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'FL',
#    'class_desc': 'ALL CLASSES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '12',
#    'state_fips_code': '12',
#    'source_desc': 'SURVEY',
#    'location_desc': 'FLORIDA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'FLORIDA',
#    'commodity_desc': 'HONEY',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'Value': '2.4',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2018,
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'Value': '2.36',
#    'freq_desc': 'ANNUAL',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'year': 2020,
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'GEORGIA',
#    'region_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '13',
#    'state_ansi': '13',
#    'watershed_desc': '',
#    'week_ending': '',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'GA',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'asd_desc': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'GEORGIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': ''},
#   {'year': 2019,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'load_time': '2021-03-18 15:00:29',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'Value': '2.67',
#    'freq_desc': 'ANNUAL',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'GEORGIA',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'GA',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'GEORGIA',
#    'region_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_ansi': '13',
#    'state_fips_code': '13',
#    'watershed_desc': '',
#    'week_ending': ''},
#   {'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'GEORGIA',
#    'state_fips_code': '13',
#    'source_desc': 'SURVEY',
#    'state_ansi': '13',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'GA',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'GEORGIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.76',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2020-03-19 15:06:59',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'year': 2018},
#   {'state_ansi': '15',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '15',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'HAWAII',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'HI',
#    'commodity_desc': 'HONEY',
#    'state_name': 'HAWAII',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '1.61',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2020},
#   {'state_alpha': 'HI',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'location_desc': 'HAWAII',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '15',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '15',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'HAWAII',
#    'commodity_desc': 'HONEY',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '1.3',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'year': 2019,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29'},
#   {'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '15',
#    'state_fips_code': '15',
#    'source_desc': 'SURVEY',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'HAWAII',
#    'region_desc': '',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'HI',
#    'commodity_desc': 'HONEY',
#    'state_name': 'HAWAII',
#    'asd_desc': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'Value': '1.92',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2020-03-19 15:06:59',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'year': 2018},
#   {'state_name': 'IDAHO',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'state_fips_code': '16',
#    'state_ansi': '16',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'IDAHO',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'ID',
#    'class_desc': 'ALL CLASSES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2020,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '1.75',
#    'watershed_code': '00000000',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'year': 2019,
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'Value': '1.62',
#    'freq_desc': 'ANNUAL',
#    'asd_desc': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'IDAHO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'IDAHO',
#    'region_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '16',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '16',
#    'week_ending': '',
#    'watershed_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ID',
#    'end_code': '00',
#    'unit_desc': '$ / LB'},
#   {'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ID',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'IDAHO',
#    'region_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '16',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '16',
#    'watershed_desc': '',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'IDAHO',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'Value': '1.96',
#    'freq_desc': 'ANNUAL',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'year': 2018,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'load_time': '2020-03-19 15:06:59',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED'},
#   {'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '5.56',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2020,
#    'load_time': '2021-03-18 15:00:29',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'IL',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '17',
#    'state_ansi': '17',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'watershed_desc': '',
#    'week_ending': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'ILLINOIS',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'ILLINOIS',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': ''},
#   {'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'watershed_code': '00000000',
#    'Value': '4.12',
#    'freq_desc': 'ANNUAL',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'year': 2019,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'IL',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'ILLINOIS',
#    'region_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '17',
#    'state_fips_code': '17',
#    'source_desc': 'SURVEY',
#    'week_ending': '',
#    'watershed_desc': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'ILLINOIS'},
#   {'state_name': 'ILLINOIS',
#    'commodity_desc': 'HONEY',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_ansi': '17',
#    'state_fips_code': '17',
#    'location_desc': 'ILLINOIS',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'IL',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'year': 2018,
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'Value': '4.83',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '4.14',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'year': 2020,
#    'location_desc': 'INDIANA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '18',
#    'state_fips_code': '18',
#    'source_desc': 'SURVEY',
#    'state_alpha': 'IN',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'INDIANA',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': ''},
#   {'commodity_desc': 'HONEY',
#    'state_name': 'INDIANA',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_ansi': '18',
#    'state_fips_code': '18',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'INDIANA',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'IN',
#    'load_time': '2021-03-18 15:00:29',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2019,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '3.78',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY'},
#   {'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '3.58',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2018,
#    'load_time': '2020-03-19 15:06:59',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'IN',
#    'state_fips_code': '18',
#    'state_ansi': '18',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'INDIANA',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'INDIANA',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': ''},
#   {'year': 2020,
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.59',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'IOWA',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'IA',
#    'state_ansi': '19',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '19',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'IOWA'},
#   {'year': 2019,
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.35',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'IOWA',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'IA',
#    'state_ansi': '19',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '19',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'watershed_desc': '',
#    'week_ending': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'IOWA'},
#   {'week_ending': '',
#    'watershed_desc': '',
#    'state_fips_code': '19',
#    'state_ansi': '19',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'IOWA',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'IA',
#    'class_desc': 'ALL CLASSES',
#    'state_name': 'IOWA',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.4',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2018},
#   {'state_name': 'KANSAS',
#    'commodity_desc': 'HONEY',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '20',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '20',
#    'location_desc': 'KANSAS',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'KS',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'year': 2020,
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'Value': '2.93',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'watershed_desc': '',
#    'week_ending': '',
#    'source_desc': 'SURVEY',
#    'state_ansi': '20',
#    'state_fips_code': '20',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'KANSAS',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'KS',
#    'class_desc': 'ALL CLASSES',
#    'state_name': 'KANSAS',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '2.35',
#    'watershed_code': '00000000',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2019},
#   {'week_ending': '',
#    'watershed_desc': '',
#    'state_fips_code': '20',
#    'state_ansi': '20',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'KANSAS',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'KS',
#    'class_desc': 'ALL CLASSES',
#    'state_name': 'KANSAS',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '3.1',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'year': 2018},
#   {'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'KENTUCKY',
#    'commodity_desc': 'HONEY',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'state_alpha': 'KY',
#    'class_desc': 'ALL CLASSES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_ansi': '21',
#    'state_fips_code': '21',
#    'location_desc': 'KENTUCKY',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'year': 2020,
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'Value': '6.25',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '4.66',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'year': 2019,
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'KY',
#    'end_code': '00',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'KENTUCKY',
#    'state_ansi': '21',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '21',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'watershed_desc': '',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'KENTUCKY'},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'KENTUCKY',
#    'commodity_desc': 'HONEY',
#    'state_alpha': 'KY',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': '$ / LB',
#    'end_code': '00',
#    'location_desc': 'KENTUCKY',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_ansi': '21',
#    'state_fips_code': '21',
#    'year': 2018,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
# ...
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'year': 2010,
#    'load_time': '2012-01-01 00:00:00',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '150',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2012-01-01 00:00:00',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'year': 2009,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '138',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'location_desc': 'NORTH DAKOTA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'state_ansi': '38',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '136',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'year': 2008,
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2012-01-01 00:00:00'},
#   {'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '96',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2007,
#    'load_time': '2012-01-01 00:00:00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'end_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ND',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'NORTH DAKOTA',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': ''},
#   {'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'Value': '91',
#    'freq_desc': 'ANNUAL',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'load_time': '2012-01-01 00:00:00',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'year': 2006,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'watershed_desc': '',
#    'week_ending': '',
#    'county_code': '',
#    'county_ansi': '',
#    'location_desc': 'NORTH DAKOTA',
#    'region_desc': '',
#    'end_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ND',
#    'commodity_desc': 'HONEY',
#    'state_name': 'NORTH DAKOTA',
#    'asd_desc': '',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'asd_desc': '',
#    'asd_code': '',
#    'county_name': '',
#    'zip_5': '',
#    'commodity_desc': 'HONEY',
#    'state_name': 'NORTH DAKOTA',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ND',
#    'end_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'state_ansi': '38',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'watershed_desc': '',
#    'week_ending': '',
#    'year': 2005,
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'load_time': '2012-01-01 00:00:00',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '83',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000'},
#   {'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'state_name': 'NORTH DAKOTA',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'end_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ND',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'year': 2004,
#    'load_time': '2012-01-01 00:00:00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '105',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'watershed_desc': '',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2012-01-01 00:00:00',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'year': 2003,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '136',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'state_ansi': '38',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'county_ansi': '',
#    'county_code': '',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2012-01-01 00:00:00',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'year': 2002,
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'freq_desc': 'ANNUAL',
#    'Value': '146',
#    'watershed_code': '00000000',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES'},
#   {'Value': '69',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'year': 2001,
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2012-01-01 00:00:00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'watershed_desc': '',
#    'week_ending': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '38',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'location_desc': 'NORTH DAKOTA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': ''},
#   {'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'agg_level_desc': 'STATE',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2012-01-01 00:00:00',
#    'year': 2000,
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'Value': '57',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': '',
#    'location_desc': 'NORTH DAKOTA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'state_ansi': '38',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00'},
#   {'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'Value': '59',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'congr_district_code': '',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2012-01-01 00:00:00',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'year': 1999,
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'state_ansi': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'week_ending': '',
#    'watershed_desc': '',
#    'county_ansi': '',
#    'county_code': '',
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'end_code': '00',
#    'unit_desc': 'CENTS / LB',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ND',
#    'commodity_desc': 'HONEY',
#    'state_name': 'NORTH DAKOTA',
#    'asd_desc': '',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'CV (%)': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_name': 'UNITED STATES',
#    'country_code': '9000',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'Value': '63',
#    'watershed_code': '00000000',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'domain_desc': 'TOTAL',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2012-01-01 00:00:00',
#    'year': 1998,
#    'region_desc': '',
#    'location_desc': 'NORTH DAKOTA',
#    'county_ansi': '',
#    'county_code': '',
#    'week_ending': '',
#    'watershed_desc': '',
#    'state_ansi': '38',
#    'source_desc': 'SURVEY',
#    'state_fips_code': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'asd_code': '',
#    'zip_5': '',
#    'county_name': '',
#    'asd_desc': '',
#    'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': ''},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'country_code': '9000',
#    'country_name': 'UNITED STATES',
#    'group_desc': 'SPECIALTY',
#    'congr_district_code': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '74',
#    'freq_desc': 'ANNUAL',
#    'watershed_code': '00000000',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'begin_code': '00',
#    'agg_level_desc': 'STATE',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'load_time': '2012-01-01 00:00:00',
#    'year': 1997,
#    'location_desc': 'NORTH DAKOTA',
#    'region_desc': '',
#    'county_code': '',
#    'county_ansi': '',
#    'week_ending': '',
#    'watershed_desc': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_ansi': '38',
#    'state_fips_code': '38',
#    'source_desc': 'SURVEY',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'unit_desc': 'CENTS / LB',
#    'end_code': '00',
#    'county_name': '',
#    'zip_5': '',
#    'asd_code': '',
#    'asd_desc': '',
#    'state_name': 'NORTH DAKOTA',
#    'commodity_desc': 'HONEY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'CV (%)': ''},
#   ...]}

# %% [markdown]
# Created a dataframe using the downloaded data

# %%
new_usda_list=usda_data['data']
usda_df=pd.DataFrame(new_usda_list)
usda_df.head(2)
usda_df.head(2)
# Out:
#   domaincat_desc domain_desc            load_time agg_level_desc begin_code  \
# 0  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29          STATE         00
# 1  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29          STATE         00
#
#                                    short_desc  year   country_name  \
# 0  HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 1  HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
#
#   country_code         sector_desc  ... source_desc statisticcat_desc  \
# 0         9000  ANIMALS & PRODUCTS  ...      SURVEY    PRICE RECEIVED
# 1         9000  ANIMALS & PRODUCTS  ...      SURVEY    PRICE RECEIVED
#
#   region_desc location_desc county_ansi county_code unit_desc end_code  \
# 0                   ALABAMA                            $ / LB       00
# 1                   ALABAMA                            $ / LB       00
#
#   state_alpha   class_desc
# 0          AL  ALL CLASSES
# 1          AL  ALL CLASSES
#
# [2 rows x 39 columns]

# %% [markdown]
# Viewed columns in order to create a column for a survey id unique to the survey for each state and time period

# %%
usda_df.columns
# Out:
# Index(['domaincat_desc', 'domain_desc', 'load_time', 'agg_level_desc',
#        'begin_code', 'short_desc', 'year', 'country_name', 'country_code',
#        'sector_desc', 'freq_desc', 'Value', 'watershed_code',
#        'congr_district_code', 'group_desc', 'util_practice_desc',
#        'reference_period_desc', 'state_name', 'commodity_desc', 'asd_code',
#        'zip_5', 'county_name', 'asd_desc', 'CV (%)', 'prodn_practice_desc',
#        'watershed_desc', 'week_ending', 'state_fips_code', 'state_ansi',
#        'source_desc', 'statisticcat_desc', 'region_desc', 'location_desc',
#        'county_ansi', 'county_code', 'unit_desc', 'end_code', 'state_alpha',
#        'class_desc'],
#       dtype='object')

# %%
usda_df.reset_index(inplace=True)
usda_df = usda_df.rename(columns = {'index': 'survey_id'})
usda_df.reset_index(drop=True)
usda_df
# Out:
#        survey_id domaincat_desc domain_desc            load_time  \
# 0              0  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 1              1  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 2              2  NOT SPECIFIED       TOTAL  2020-03-19 15:06:59
# 3              3  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 4              4  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# ...          ...            ...         ...                  ...
# 21637      21637  NOT SPECIFIED       TOTAL  2017-08-01 15:00:29
# 21638      21638  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21639      21639  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21640      21640  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21641      21641  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
#
#       agg_level_desc begin_code  \
# 0              STATE         00
# 1              STATE         00
# 2              STATE         00
# 3              STATE         00
# 4              STATE         00
# ...              ...        ...
# 21637          STATE         10
# 21638          STATE         01
# 21639          STATE         04
# 21640          STATE         07
# 21641          STATE         10
#
#                                               short_desc  year   country_name  \
# 0             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 1             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
# 2             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2018  UNITED STATES
# 3             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 4             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
# ...                                                  ...   ...            ...
# 21637  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2016  UNITED STATES
# 21638  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21639  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21640  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21641  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
#
#       country_code  ... source_desc statisticcat_desc region_desc  \
# 0             9000  ...      SURVEY    PRICE RECEIVED
# 1             9000  ...      SURVEY    PRICE RECEIVED
# 2             9000  ...      SURVEY    PRICE RECEIVED
# 3             9000  ...      SURVEY    PRICE RECEIVED
# 4             9000  ...      SURVEY    PRICE RECEIVED
# ...            ...  ...         ...               ...         ...
# 21637         9000  ...      SURVEY         INVENTORY
# 21638         9000  ...      SURVEY         INVENTORY
# 21639         9000  ...      SURVEY         INVENTORY
# 21640         9000  ...      SURVEY         INVENTORY
# 21641         9000  ...      SURVEY         INVENTORY
#
#       location_desc county_ansi county_code        unit_desc end_code  \
# 0           ALABAMA                                   $ / LB       00
# 1           ALABAMA                                   $ / LB       00
# 2           ALABAMA                                   $ / LB       00
# 3           ARIZONA                                   $ / LB       00
# 4           ARIZONA                                   $ / LB       00
# ...             ...         ...         ...              ...      ...
# 21637  OTHER STATES                          PCT OF COLONIES       12
# 21638  OTHER STATES                          PCT OF COLONIES       03
# 21639  OTHER STATES                          PCT OF COLONIES       06
# 21640  OTHER STATES                          PCT OF COLONIES       09
# 21641  OTHER STATES                          PCT OF COLONIES       12
#
#       state_alpha    class_desc
# 0              AL   ALL CLASSES
# 1              AL   ALL CLASSES
# 2              AL   ALL CLASSES
# 3              AZ   ALL CLASSES
# 4              AZ   ALL CLASSES
# ...           ...           ...
# 21637          OT  BEE COLONIES
# 21638          OT  BEE COLONIES
# 21639          OT  BEE COLONIES
# 21640          OT  BEE COLONIES
# 21641          OT  BEE COLONIES
#
# [21642 rows x 40 columns]

# %% [markdown]
# Generated the marketing ids by concatenating a code for the reference period description, state abbreviation, and year.

# %%
# concatenating the columns
usda_df['marketing_id'] = usda_df['reference_period_desc'].map(str) + usda_df['state_alpha'].map(str)+usda_df['year'].map(str)
usda_df
# Out:
#        survey_id domaincat_desc domain_desc            load_time  \
# 0              0  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 1              1  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 2              2  NOT SPECIFIED       TOTAL  2020-03-19 15:06:59
# 3              3  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 4              4  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# ...          ...            ...         ...                  ...
# 21637      21637  NOT SPECIFIED       TOTAL  2017-08-01 15:00:29
# 21638      21638  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21639      21639  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21640      21640  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21641      21641  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
#
#       agg_level_desc begin_code  \
# 0              STATE         00
# 1              STATE         00
# 2              STATE         00
# 3              STATE         00
# 4              STATE         00
# ...              ...        ...
# 21637          STATE         10
# 21638          STATE         01
# 21639          STATE         04
# 21640          STATE         07
# 21641          STATE         10
#
#                                               short_desc  year   country_name  \
# 0             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 1             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
# 2             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2018  UNITED STATES
# 3             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 4             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
# ...                                                  ...   ...            ...
# 21637  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2016  UNITED STATES
# 21638  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21639  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21640  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21641  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
#
#       country_code  ... statisticcat_desc region_desc location_desc  \
# 0             9000  ...    PRICE RECEIVED                   ALABAMA
# 1             9000  ...    PRICE RECEIVED                   ALABAMA
# 2             9000  ...    PRICE RECEIVED                   ALABAMA
# 3             9000  ...    PRICE RECEIVED                   ARIZONA
# 4             9000  ...    PRICE RECEIVED                   ARIZONA
# ...            ...  ...               ...         ...           ...
# 21637         9000  ...         INVENTORY              OTHER STATES
# 21638         9000  ...         INVENTORY              OTHER STATES
# 21639         9000  ...         INVENTORY              OTHER STATES
# 21640         9000  ...         INVENTORY              OTHER STATES
# 21641         9000  ...         INVENTORY              OTHER STATES
#
#       county_ansi county_code        unit_desc end_code state_alpha  \
# 0                                       $ / LB       00          AL
# 1                                       $ / LB       00          AL
# 2                                       $ / LB       00          AL
# 3                                       $ / LB       00          AZ
# 4                                       $ / LB       00          AZ
# ...           ...         ...              ...      ...         ...
# 21637                          PCT OF COLONIES       12          OT
# 21638                          PCT OF COLONIES       03          OT
# 21639                          PCT OF COLONIES       06          OT
# 21640                          PCT OF COLONIES       09          OT
# 21641                          PCT OF COLONIES       12          OT
#
#          class_desc          marketing_id
# 0       ALL CLASSES  MARKETING YEARAL2020
# 1       ALL CLASSES  MARKETING YEARAL2019
# 2       ALL CLASSES  MARKETING YEARAL2018
# 3       ALL CLASSES  MARKETING YEARAZ2020
# 4       ALL CLASSES  MARKETING YEARAZ2019
# ...             ...                   ...
# 21637  BEE COLONIES    OCT THRU DECOT2016
# 21638  BEE COLONIES    JAN THRU MAROT2015
# 21639  BEE COLONIES    APR THRU JUNOT2015
# 21640  BEE COLONIES    JUL THRU SEPOT2015
# 21641  BEE COLONIES    OCT THRU DECOT2015
#
# [21642 rows x 41 columns]

# %% [markdown]
# Capitalized column name for Value

# %%
usda_df['value'] = usda_df['Value']

usda_df
# Out:
#        survey_id domaincat_desc domain_desc            load_time  \
# 0              0  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 1              1  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 2              2  NOT SPECIFIED       TOTAL  2020-03-19 15:06:59
# 3              3  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# 4              4  NOT SPECIFIED       TOTAL  2021-03-18 15:00:29
# ...          ...            ...         ...                  ...
# 21637      21637  NOT SPECIFIED       TOTAL  2017-08-01 15:00:29
# 21638      21638  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21639      21639  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21640      21640  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
# 21641      21641  NOT SPECIFIED       TOTAL  2016-05-12 15:09:03
#
#       agg_level_desc begin_code  \
# 0              STATE         00
# 1              STATE         00
# 2              STATE         00
# 3              STATE         00
# 4              STATE         00
# ...              ...        ...
# 21637          STATE         10
# 21638          STATE         01
# 21639          STATE         04
# 21640          STATE         07
# 21641          STATE         10
#
#                                               short_desc  year   country_name  \
# 0             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 1             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
# 2             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2018  UNITED STATES
# 3             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2020  UNITED STATES
# 4             HONEY - PRICE RECEIVED, MEASURED IN $ / LB  2019  UNITED STATES
# ...                                                  ...   ...            ...
# 21637  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2016  UNITED STATES
# 21638  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21639  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21640  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
# 21641  HONEY, BEE COLONIES, RENOVATED - INVENTORY, ME...  2015  UNITED STATES
#
#       country_code  ... region_desc location_desc county_ansi county_code  \
# 0             9000  ...                   ALABAMA
# 1             9000  ...                   ALABAMA
# 2             9000  ...                   ALABAMA
# 3             9000  ...                   ARIZONA
# 4             9000  ...                   ARIZONA
# ...            ...  ...         ...           ...         ...         ...
# 21637         9000  ...              OTHER STATES
# 21638         9000  ...              OTHER STATES
# 21639         9000  ...              OTHER STATES
# 21640         9000  ...              OTHER STATES
# 21641         9000  ...              OTHER STATES
#
#              unit_desc end_code state_alpha    class_desc  \
# 0               $ / LB       00          AL   ALL CLASSES
# 1               $ / LB       00          AL   ALL CLASSES
# 2               $ / LB       00          AL   ALL CLASSES
# 3               $ / LB       00          AZ   ALL CLASSES
# 4               $ / LB       00          AZ   ALL CLASSES
# ...                ...      ...         ...           ...
# 21637  PCT OF COLONIES       12          OT  BEE COLONIES
# 21638  PCT OF COLONIES       03          OT  BEE COLONIES
# 21639  PCT OF COLONIES       06          OT  BEE COLONIES
# 21640  PCT OF COLONIES       09          OT  BEE COLONIES
# 21641  PCT OF COLONIES       12          OT  BEE COLONIES
#
#                marketing_id value
# 0      MARKETING YEARAL2020  5.43
# 1      MARKETING YEARAL2019  3.38
# 2      MARKETING YEARAL2018  3.72
# 3      MARKETING YEARAZ2020  2.18
# 4      MARKETING YEARAZ2019  2.04
# ...                     ...   ...
# 21637    OCT THRU DECOT2016     0
# 21638    JAN THRU MAROT2015     2
# 21639    APR THRU JUNOT2015    18
# 21640    JUL THRU SEPOT2015     6
# 21641    OCT THRU DECOT2015     0
#
# [21642 rows x 42 columns]

# %% [markdown]
# Removed rows with null values

# %%
usda_df.dropna(inplace=True)

# %% [markdown]
# Compiled information to be loaded into the location table.  Named this dataframe usda_location

# %%
usda_location = usda_df[['country_name', 'country_code', 'state_name', 'state_alpha','state_fips_code', 'marketing_id']]
usda_location
# Out:
#         country_name country_code    state_name state_alpha state_fips_code  \
# 0      UNITED STATES         9000       ALABAMA          AL              01
# 1      UNITED STATES         9000       ALABAMA          AL              01
# 2      UNITED STATES         9000       ALABAMA          AL              01
# 3      UNITED STATES         9000       ARIZONA          AZ              04
# 4      UNITED STATES         9000       ARIZONA          AZ              04
# ...              ...          ...           ...         ...             ...
# 21637  UNITED STATES         9000  OTHER STATES          OT              98
# 21638  UNITED STATES         9000  OTHER STATES          OT              98
# 21639  UNITED STATES         9000  OTHER STATES          OT              98
# 21640  UNITED STATES         9000  OTHER STATES          OT              98
# 21641  UNITED STATES         9000  OTHER STATES          OT              98
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %% [markdown]
# Compiled information to be loaded into the period table.  Named the dataframe usda_period

# %%
usda_period = usda_df[['survey_id','freq_desc','year','load_time','state_name', 'marketing_id']]
usda_period
# Out:
#        survey_id freq_desc  year            load_time    state_name  \
# 0              0    ANNUAL  2020  2021-03-18 15:00:29       ALABAMA
# 1              1    ANNUAL  2019  2021-03-18 15:00:29       ALABAMA
# 2              2    ANNUAL  2018  2020-03-19 15:06:59       ALABAMA
# 3              3    ANNUAL  2020  2021-03-18 15:00:29       ARIZONA
# 4              4    ANNUAL  2019  2021-03-18 15:00:29       ARIZONA
# ...          ...       ...   ...                  ...           ...
# 21637      21637   MONTHLY  2016  2017-08-01 15:00:29  OTHER STATES
# 21638      21638   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21639      21639   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21640      21640   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21641      21641   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %% [markdown]
# Compiled the information to be loaded into the product table.  Named this dataframe usda_product

# %%
usda_product = usda_df[['survey_id','sector_desc','class_desc','group_desc','commodity_desc', 'marketing_id']]
usda_product
# Out:
#        survey_id         sector_desc    class_desc group_desc commodity_desc  \
# 0              0  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 1              1  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 2              2  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 3              3  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 4              4  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# ...          ...                 ...           ...        ...            ...
# 21637      21637  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21638      21638  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21639      21639  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21640      21640  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21641      21641  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %% [markdown]
# Created a dataframe containing all of the information that will be contained within the various loss of bees tables.

# %%
#General dataframe for loss of bees
usda_causes_df=usda_df[['survey_id','value', 'domain_desc', 'unit_desc','short_desc','statisticcat_desc', 'marketing_id']]
usda_causes_df['short_desc'].unique()
# Out:
# array(['HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#        'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#        'HONEY - PRODUCTION, MEASURED IN $',
#        'HONEY - PRODUCTION, MEASURED IN LB',
#        'HONEY - PRODUCTION, MEASURED IN LB / COLONY',
#        'HONEY - STOCKS, MEASURED IN LB',
#        'HONEY, BEE COLONIES, AFFECTED BY DISEASE - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL VARROA MITES)) - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY VARROA MITES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES - ADDED & REPLACED, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - INVENTORY, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DISORDER, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN PCT OF COLONIES'],
#       dtype=object)

# %% [markdown]
# Created a dataframe for the Colony Collapse Disorder table.  This also required the elimination of unneccessary commas and converting the Value column into a type float.

# %%
#Extracted data with CCD for 2020 year (90 rows, 8 columns)
usda_ccd_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
#Removed "," from value columns
usda_ccd_df['value']=usda_ccd_df['value'].str.replace(',','')
#converted value column in CCD 2020 from str to float
usda_ccd_df['value'] = usda_ccd_df['value'].astype(float)
usda_ccd_df
# Out:
# <ipython-input-15-f4d350cf129e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_ccd_df['value']=usda_ccd_df['value'].str.replace(',','')
# <ipython-input-15-f4d350cf129e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_ccd_df['value'] = usda_ccd_df['value'].astype(float)
#        survey_id   value domain_desc unit_desc  \
# 17562      17562    70.0       TOTAL  COLONIES
# 17563      17563   410.0       TOTAL  COLONIES
# 17564      17564   140.0       TOTAL  COLONIES
# 17565      17565   180.0       TOTAL  COLONIES
# 17566      17566   110.0       TOTAL  COLONIES
# ...          ...     ...         ...       ...
# 17785      17785  1100.0       TOTAL  COLONIES
# 17786      17786  1500.0       TOTAL  COLONIES
# 17787      17787   140.0       TOTAL  COLONIES
# 17788      17788     0.0       TOTAL  COLONIES
# 17789      17789     0.0       TOTAL  COLONIES
#
#                                               short_desc  \
# 17562  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17563  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17564  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17565  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17566  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ...                                                  ...
# 17785  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17786  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17787  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17788  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17789  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
#
#                     statisticcat_desc        marketing_id
# 17562  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MARAL2020
# 17563  LOSS, COLONY COLLAPSE DISORDER  APR THRU JUNAL2020
# 17564  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MARAL2019
# 17565  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPAL2019
# 17566  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECAL2019
# ...                               ...                 ...
# 17785  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPWY2019
# 17786  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECWY2019
# 17787  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MAROT2019
# 17788  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPOT2019
# 17789  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECOT2019
#
# [228 rows x 7 columns]

# %% [markdown]
# Similarly created a dataframe for the pests table.  This required the same removal of commas and retyping as a float.

# %%
usda_pests_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY PESTS")]
#Removed "," from value columns
usda_pests_df['value']=usda_pests_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_pests_df['value'] = pd.to_numeric(usda_pests_df['value'], errors='coerce')
usda_pests_df


usda_pests_df.dropna(inplace=True)
# Out:
# <ipython-input-16-982183c74a21>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df['value']=usda_pests_df['value'].str.replace(',','')
# <ipython-input-16-982183c74a21>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df['value'] = pd.to_numeric(usda_pests_df['value'], errors='coerce')
# <ipython-input-16-982183c74a21>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df.dropna(inplace=True)

# %%
usda_inventory_max_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("INVENTORY, MAX,")]
#Removed "," from value columns
usda_inventory_max_df['value']=usda_inventory_max_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_inventory_max_df['value'] = pd.to_numeric(usda_inventory_max_df['value'], errors='coerce')
usda_inventory_max_df
# Out:
# <ipython-input-17-0cdd722cf364>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_max_df['value']=usda_inventory_max_df['value'].str.replace(',','')
# <ipython-input-17-0cdd722cf364>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_max_df['value'] = pd.to_numeric(usda_inventory_max_df['value'], errors='coerce')
#        survey_id  value domain_desc unit_desc  \
# 16596      16596   8000       TOTAL  COLONIES
# 16597      16597   8500       TOTAL  COLONIES
# 16598      16598   5500       TOTAL  COLONIES
# 16599      16599   7000       TOTAL  COLONIES
# 16600      16600   6000       TOTAL  COLONIES
# ...          ...    ...         ...       ...
# 17557      17557   6460       TOTAL  COLONIES
# 17558      17558   8990       TOTAL  COLONIES
# 17559      17559  11200       TOTAL  COLONIES
# 17560      17560  12280       TOTAL  COLONIES
# 17561      17561  12560       TOTAL  COLONIES
#
#                                               short_desc statisticcat_desc  \
# 16596  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16597  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16598  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16599  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16600  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# ...                                                  ...               ...
# 17557  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17558  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17559  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17560  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17561  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
#
#              marketing_id
# 16596  JAN THRU MARAL2020
# 16597  APR THRU JUNAL2020
# 16598  JAN THRU MARAL2019
# 16599  JUL THRU SEPAL2019
# 16600  OCT THRU DECAL2019
# ...                   ...
# 17557  OCT THRU DECOT2016
# 17558  JAN THRU MAROT2015
# 17559  APR THRU JUNOT2015
# 17560  JUL THRU SEPOT2015
# 17561  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# Also created a dataframe for the inventory_max table.  This required the same removal of commas and retyping as a float.

# %%
usda_other_causes_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY OTHER CAUSES")]
#Removed "," from value columns
usda_other_causes_df['value']=usda_other_causes_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_other_causes_df['value'] = pd.to_numeric(usda_other_causes_df['value'], errors='coerce')

usda_other_causes_df

usda_other_causes_df.dropna(inplace=True)
# Out:
# <ipython-input-19-0815bd507425>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df['value']=usda_other_causes_df['value'].str.replace(',','')
# <ipython-input-19-0815bd507425>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df['value'] = pd.to_numeric(usda_other_causes_df['value'], errors='coerce')
# <ipython-input-19-0815bd507425>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df.dropna(inplace=True)

# %% [markdown]
# Similarly created a dataframe for the pesticides table.  This required the same removal of commas and retyping as a float.

# %%
usda_pesticides_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
#Removed "," from value columns
usda_pesticides_df['value']=usda_pesticides_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_pesticides_df['value'] = pd.to_numeric(usda_pesticides_df['value'], errors='coerce')

usda_pesticides_df


usda_pesticides_df.dropna(inplace=True)
# Out:
# <ipython-input-20-7b2e3aa6f06c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df['value']=usda_pesticides_df['value'].str.replace(',','')
# <ipython-input-20-7b2e3aa6f06c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df['value'] = pd.to_numeric(usda_pesticides_df['value'], errors='coerce')
# <ipython-input-20-7b2e3aa6f06c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df.dropna(inplace=True)

# %% [markdown]
# Also created a dataframe for the disease table.  This required the same removal of commas and retyping as a float.

# %%
usda_disease_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY DISEASE")]
#Removed "," from value columns
usda_disease_df['value']=usda_disease_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_disease_df['value'] = pd.to_numeric(usda_disease_df['value'], errors='coerce')
usda_disease_df.dropna(inplace=True)
usda_disease_df
# Out:
# <ipython-input-21-c4308274e7e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df['value']=usda_disease_df['value'].str.replace(',','')
# <ipython-input-21-c4308274e7e7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df['value'] = pd.to_numeric(usda_disease_df['value'], errors='coerce')
# <ipython-input-21-c4308274e7e7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df.dropna(inplace=True)
#       survey_id  value domain_desc        unit_desc  \
# 7391       7391    1.6       TOTAL  PCT OF COLONIES
# 7392       7392    1.8       TOTAL  PCT OF COLONIES
# 7393       7393    2.9       TOTAL  PCT OF COLONIES
# 7394       7394    0.6       TOTAL  PCT OF COLONIES
# 7395       7395    1.9       TOTAL  PCT OF COLONIES
# ...         ...    ...         ...              ...
# 8351       8351    9.3       TOTAL  PCT OF COLONIES
# 8352       8352    0.0       TOTAL  PCT OF COLONIES
# 8353       8353    0.0       TOTAL  PCT OF COLONIES
# 8354       8354    0.0       TOTAL  PCT OF COLONIES
# 8355       8355    0.0       TOTAL  PCT OF COLONIES
#
#                                              short_desc statisticcat_desc  \
# 7391  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7392  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7393  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7394  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7395  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# ...                                                 ...               ...
# 8351  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8352  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8353  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8354  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8355  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
#
#             marketing_id
# 7391  APR THRU JUNAL2020
# 7392  JAN THRU MARAL2019
# 7393  JUL THRU SEPAL2019
# 7394  OCT THRU DECAL2019
# 7395  JAN THRU MARAL2018
# ...                  ...
# 8351  OCT THRU DECOT2016
# 8352  JAN THRU MAROT2015
# 8353  APR THRU JUNOT2015
# 8354  JUL THRU SEPOT2015
# 8355  OCT THRU DECOT2015
#
# [946 rows x 7 columns]

# %% [markdown]
# Additionally created a dataframe for the varroa_mites table.  This required the same removal of commas and retyping as a float.

# %%
usda_varroa_mites_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY VARROA MITES")]
#Removed "," from value columns
usda_varroa_mites_df['value']=usda_varroa_mites_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_varroa_mites_df['value'] = pd.to_numeric(usda_varroa_mites_df['value'], errors='coerce')
usda_varroa_mites_df
# Out:
# <ipython-input-22-c6e73bae6444>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_varroa_mites_df['value']=usda_varroa_mites_df['value'].str.replace(',','')
# <ipython-input-22-c6e73bae6444>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_varroa_mites_df['value'] = pd.to_numeric(usda_varroa_mites_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 12220      12220   12.4       TOTAL  PCT OF COLONIES
# 12221      12221   28.5       TOTAL  PCT OF COLONIES
# 12222      12222   27.2       TOTAL  PCT OF COLONIES
# 12223      12223   30.6       TOTAL  PCT OF COLONIES
# 12224      12224   46.7       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 13181      13181   24.1       TOTAL  PCT OF COLONIES
# 13182      13182    0.8       TOTAL  PCT OF COLONIES
# 13183      13183   36.3       TOTAL  PCT OF COLONIES
# 13184      13184    8.8       TOTAL  PCT OF COLONIES
# 13185      13185    8.2       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 12220  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12221  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12222  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12223  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12224  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# ...                                                  ...               ...
# 13181  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13182  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13183  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13184  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13185  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
#
#              marketing_id
# 12220  JAN THRU MARAL2020
# 12221  APR THRU JUNAL2020
# 12222  JAN THRU MARAL2019
# 12223  JUL THRU SEPAL2019
# 12224  OCT THRU DECAL2019
# ...                   ...
# 13181  OCT THRU DECOT2016
# 13182  JAN THRU MAROT2015
# 13183  APR THRU JUNOT2015
# 13184  JUL THRU SEPOT2015
# 13185  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %% [markdown]
# Finally, created a dataframe for the pests table.  This required the same removal of commas and retyping as a float.

# %%
usda_unknown_causes_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY UNKNOWN CAUSES")]
#Removed "," from value columns
usda_unknown_causes_df['value']=usda_unknown_causes_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_unknown_causes_df['value'] = pd.to_numeric(usda_unknown_causes_df['value'], errors='coerce')


usda_unknown_causes_df


usda_unknown_causes_df.dropna(inplace=True)
# Out:
# <ipython-input-23-a0877b7e9b02>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df['value']=usda_unknown_causes_df['value'].str.replace(',','')
# <ipython-input-23-a0877b7e9b02>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df['value'] = pd.to_numeric(usda_unknown_causes_df['value'], errors='coerce')
# <ipython-input-23-a0877b7e9b02>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df.dropna(inplace=True)

# %% [markdown]
# Imprted modules needed for creation of tables in postgresql

# %%
import requests
import numpy as np
import pandas as pd
import time
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats
import psycopg2
import time
import pandas as pd
from sqlalchemy import create_engine
import psycopg2.extras as extras
import io

# %%
#connecting python to postgres sql
#loopback host ip="127.0.0.1". can also be used to be specific.

# %% [markdown]
# Created a function called load which will be used to create the tables and populate them with the dataframes which are saved in csv files.

# %%
def load(df, name):
    engine = create_engine('postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/Bee2')

    df.head(0).to_sql( name, engine, if_exists='replace',index=False) #drops old table and creates new empty table

    conn = engine.raw_connection()
    cur = conn.cursor()
    output = io.StringIO()
    df.to_csv(output, sep='\t', header=False, index=False)
    output.seek(0)
    contents = output.getvalue()
    cur.copy_from(output, name, null="") # null values become ''
    conn.commit()
    print(str(name) + ' done')

# %% [markdown]
# Created the csv files which will be loaded into postgresql

# %%
usda_location.to_csv('location.csv', index=False)
usda_period.to_csv('period.csv', index=False)
usda_product.to_csv('product.csv', index=False)
usda_ccd_df.to_csv('ccd.csv', index=False)
usda_pests_df.to_csv('pests.csv', index=False)
usda_inventory_max_df.to_csv('inventory_max.csv', index=False)
usda_other_causes_df.to_csv('other_causes.csv', index=False)
usda_pesticides_df.to_csv('pesticides.csv', index=False)
usda_disease_df.to_csv('disease.csv', index=False)
usda_unknown_causes_df.to_csv('unknown_causes.csv', index=False)
usda_varroa_mites_df.to_csv('varroa_mites.csv', index=False)

# %% [markdown]
# Created each table and populated it with the information via the function created above

# %%
load(usda_period, 'period')
load(usda_product, 'product')
load(usda_ccd_df, 'colony_collapse_disorder')
load(usda_inventory_max_df, 'inventory_max')
load(usda_other_causes_df, 'other_causes')
load(usda_pests_df, 'pests')
load(usda_varroa_mites_df, 'varroa_mites')
load(usda_unknown_causes_df, 'unknown_causes')
load(usda_pesticides_df, 'pesticides')
load(usda_disease_df, 'disease')
load(usda_location, 'location')
# Out:
# period done
# product done
# colony_collapse_disorder done
# inventory_max done
# other_causes done
# pests done
# varroa_mites done
# unknown_causes done
# pesticides done
# disease done
